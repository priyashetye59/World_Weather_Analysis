# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.(London)
london_url = url + "&q=" + "London"

# %%
# Make a 'Get' request for the city weather.(London)
london_weather = requests.get(london_url)
london_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.(London)
london_weather.text
# Out:
# '{"coord":{"lon":-0.1257,"lat":51.5085},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":54.54,"feels_like":53.73,"temp_min":51.85,"temp_max":58.08,"pressure":999,"humidity":86},"visibility":10000,"wind":{"speed":17.27,"deg":210,"gust":28.77},"clouds":{"all":75},"dt":1667262585,"sys":{"type":2,"id":2075535,"country":"GB","sunrise":1667285618,"sunset":1667320465},"timezone":0,"id":2643743,"name":"London","cod":200}'

# %%
# Get the JSON text of the 'Get' request.(London)
london_weather.json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 54.54,
#   'feels_like': 53.73,
#   'temp_min': 51.85,
#   'temp_max': 58.08,
#   'pressure': 999,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 210, 'gust': 28.77},
#  'clouds': {'all': 75},
#  'dt': 1667262585,
#  'sys': {'type': 2,
#   'id': 2075535,
#   'country': 'GB',
#   'sunrise': 1667285618,
#   'sunset': 1667320465},
#  'timezone': 0,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
london_current_description = london_weather.json()["weather"][0]["description"]
london_name = london_weather.json()["name"]
london_current_description
london_name
# Out:
# 'London'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | galesong
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | alice springs
# Processing Record 6 of Set 1 | christchurch
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | shiogama
# Processing Record 9 of Set 1 | oeiras do para
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | tomatlan
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | dembi dolo
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | bilma
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | iquique
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | vaitape
# Processing Record 26 of Set 1 | murgab
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | mount isa
# Processing Record 29 of Set 1 | colan
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | mananara
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | vila franca do campo
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | mildura
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | beckley
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | marsa matruh
# Processing Record 48 of Set 1 | fuyang
# Processing Record 49 of Set 1 | mattru
# Processing Record 50 of Set 1 | harper
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | coihaique
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | namatanai
# Processing Record 5 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | yartsevo
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | vakhtan
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | tombouctou
# Processing Record 14 of Set 2 | portland
# Processing Record 15 of Set 2 | torres
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | pemba
# Processing Record 19 of Set 2 | qui nhon
# Processing Record 20 of Set 2 | vila
# Processing Record 21 of Set 2 | nizhniy kuranakh
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | sidi ali
# Processing Record 24 of Set 2 | tuatapere
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 2 | qaqortoq
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | aljezur
# Processing Record 32 of Set 2 | nuuk
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | rio grande
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | carambei
# Processing Record 37 of Set 2 | sorsk
# Processing Record 38 of Set 2 | obidos
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | ostrovnoy
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | macae
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | twentynine palms
# Processing Record 45 of Set 2 | nemuro
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | esperance
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | olga
# Processing Record 1 of Set 3 | buarcos
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | gazanjyk
# Processing Record 4 of Set 3 | mvuma
# Processing Record 5 of Set 3 | mareeba
# Processing Record 6 of Set 3 | vestmanna
# Processing Record 7 of Set 3 | bedford
# Processing Record 8 of Set 3 | dawei
# Processing Record 9 of Set 3 | plettenberg bay
# Processing Record 10 of Set 3 | nguru
# Processing Record 11 of Set 3 | hohhot
# Processing Record 12 of Set 3 | matara
# Processing Record 13 of Set 3 | beidao
# Processing Record 14 of Set 3 | talovaya
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | kajaani
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | okhotsk
# Processing Record 21 of Set 3 | freeport
# Processing Record 22 of Set 3 | the valley
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | bunumbu
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | cayhagan
# Processing Record 28 of Set 3 | kirakira
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | vestmannaeyjar
# Processing Record 31 of Set 3 | puerto escondido
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | tazmalt
# Processing Record 34 of Set 3 | kloulklubed
# Processing Record 35 of Set 3 | champerico
# Processing Record 36 of Set 3 | lompoc
# Processing Record 37 of Set 3 | turtas
# Processing Record 38 of Set 3 | huilong
# Processing Record 39 of Set 3 | barra patuca
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | vao
# Processing Record 42 of Set 3 | kibala
# Processing Record 43 of Set 3 | folldal
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | smithers
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | dwarka
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | lasa
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | gold coast
# Processing Record 4 of Set 4 | dali
# Processing Record 5 of Set 4 | mecca
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | santa rosa
# Processing Record 8 of Set 4 | mandalgovi
# Processing Record 9 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 4 | port hardy
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | weihai
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | otane
# Processing Record 16 of Set 4 | inhambane
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | coolum beach
# Processing Record 19 of Set 4 | kurya
# Processing Record 20 of Set 4 | tateyama
# Processing Record 21 of Set 4 | santa cecilia
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | kamenka
# Processing Record 24 of Set 4 | charlottesville
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | san jose
# Processing Record 27 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | grandview
# Processing Record 30 of Set 4 | revuca
# Processing Record 31 of Set 4 | areosa
# Processing Record 32 of Set 4 | presidencia roque saenz pena
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | paamiut
# Processing Record 35 of Set 4 | puerto madryn
# Processing Record 36 of Set 4 | cruzeiro do sul
# Processing Record 37 of Set 4 | yangliuqing
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | koumac
# Processing Record 40 of Set 4 | axim
# Processing Record 41 of Set 4 | ilulissat
# Processing Record 42 of Set 4 | bahia blanca
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | severnyy
# Processing Record 45 of Set 4 | shyryayeve
# Processing Record 46 of Set 4 | marysville
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | san ramon de la nueva oran
# Processing Record 50 of Set 4 | taraz
# Processing Record 1 of Set 5 | oranjestad
# Processing Record 2 of Set 5 | aksu
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | muroto
# Processing Record 5 of Set 5 | gamba
# Processing Record 6 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 5 | cortes
# Processing Record 8 of Set 5 | kvarkeno
# Processing Record 9 of Set 5 | zhuhai
# Processing Record 10 of Set 5 | itaiba
# Processing Record 11 of Set 5 | doha
# Processing Record 12 of Set 5 | yumen
# Processing Record 13 of Set 5 | gigmoto
# Processing Record 14 of Set 5 | malartic
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | kralendijk
# Processing Record 17 of Set 5 | muzquiz
# City not found. Skipping...
# Processing Record 18 of Set 5 | san vicente
# Processing Record 19 of Set 5 | nantucket
# Processing Record 20 of Set 5 | tefe
# Processing Record 21 of Set 5 | anshun
# Processing Record 22 of Set 5 | pangnirtung
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | boksitogorsk
# Processing Record 28 of Set 5 | bathsheba
# Processing Record 29 of Set 5 | belaya gora
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | cabedelo
# Processing Record 33 of Set 5 | jalu
# Processing Record 34 of Set 5 | norman wells
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | orahovac
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | acari
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | heishan
# Processing Record 41 of Set 5 | mahibadhoo
# Processing Record 42 of Set 5 | camopi
# Processing Record 43 of Set 5 | agadez
# Processing Record 44 of Set 5 | quixada
# Processing Record 45 of Set 5 | merauke
# Processing Record 46 of Set 5 | quatre cocos
# Processing Record 47 of Set 5 | radford
# Processing Record 48 of Set 5 | oranjemund
# Processing Record 49 of Set 5 | salalah
# Processing Record 50 of Set 5 | gravdal
# Processing Record 1 of Set 6 | kuching
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | eyl
# Processing Record 4 of Set 6 | abay
# Processing Record 5 of Set 6 | micheweni
# Processing Record 6 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | kutum
# Processing Record 9 of Set 6 | vikhorevka
# Processing Record 10 of Set 6 | cagliari
# Processing Record 11 of Set 6 | rio gallegos
# Processing Record 12 of Set 6 | kathmandu
# Processing Record 13 of Set 6 | padilla
# Processing Record 14 of Set 6 | teya
# Processing Record 15 of Set 6 | bichena
# Processing Record 16 of Set 6 | pochutla
# Processing Record 17 of Set 6 | broken hill
# Processing Record 18 of Set 6 | aswan
# Processing Record 19 of Set 6 | omboue
# Processing Record 20 of Set 6 | mapastepec
# Processing Record 21 of Set 6 | chernyshevskiy
# Processing Record 22 of Set 6 | boa vista
# Processing Record 23 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 6 | diu
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | atbasar
# Processing Record 27 of Set 6 | cukai
# Processing Record 28 of Set 6 | kuusamo
# Processing Record 29 of Set 6 | uthal
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | tatarskaya pishlya
# Processing Record 32 of Set 6 | khatanga
# Processing Record 33 of Set 6 | bereda
# Processing Record 34 of Set 6 | gorontalo
# Processing Record 35 of Set 6 | oussouye
# Processing Record 36 of Set 6 | mayo
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | ojinaga
# Processing Record 39 of Set 6 | belmonte
# Processing Record 40 of Set 6 | enem
# Processing Record 41 of Set 6 | carutapera
# Processing Record 42 of Set 6 | wad madani
# Processing Record 43 of Set 6 | oytal
# Processing Record 44 of Set 6 | nadym
# Processing Record 45 of Set 6 | san jeronimo
# Processing Record 46 of Set 6 | khed
# Processing Record 47 of Set 6 | shingu
# Processing Record 48 of Set 6 | olafsvik
# Processing Record 49 of Set 6 | maragogi
# Processing Record 50 of Set 6 | havelock
# Processing Record 1 of Set 7 | mpika
# Processing Record 2 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 3 of Set 7 | brainerd
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 6 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 7 | sayabec
# City not found. Skipping...
# Processing Record 8 of Set 7 | noumea
# Processing Record 9 of Set 7 | bar harbor
# Processing Record 10 of Set 7 | taltal
# Processing Record 11 of Set 7 | lindi
# Processing Record 12 of Set 7 | innisfail
# Processing Record 13 of Set 7 | weligama
# Processing Record 14 of Set 7 | namibe
# Processing Record 15 of Set 7 | iralaya
# Processing Record 16 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 7 | necochea
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | calvinia
# Processing Record 20 of Set 7 | xining
# Processing Record 21 of Set 7 | itoman
# Processing Record 22 of Set 7 | yerofey pavlovich
# Processing Record 23 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 7 | ripoll
# Processing Record 25 of Set 7 | vanavara
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | emerald
# Processing Record 28 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 7 | cap malheureux
# Processing Record 30 of Set 7 | znamenskoye
# Processing Record 31 of Set 7 | claremorris
# Processing Record 32 of Set 7 | amalapuram
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | gebze
# Processing Record 35 of Set 7 | galveston
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | guiratinga
# Processing Record 39 of Set 7 | puerto el triunfo
# Processing Record 40 of Set 7 | harrismith
# Processing Record 41 of Set 7 | half moon bay
# Processing Record 42 of Set 7 | ciudad guayana
# Processing Record 43 of Set 7 | dabhol
# Processing Record 44 of Set 7 | santiago
# Processing Record 45 of Set 7 | harrison
# Processing Record 46 of Set 7 | amapa
# Processing Record 47 of Set 7 | kudahuvadhoo
# Processing Record 48 of Set 7 | danilovka
# Processing Record 49 of Set 7 | salto
# Processing Record 50 of Set 7 | contamana
# Processing Record 1 of Set 8 | dracena
# Processing Record 2 of Set 8 | cabo san lucas
# Processing Record 3 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 8 | oshnaviyeh
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | dingle
# Processing Record 8 of Set 8 | fort nelson
# Processing Record 9 of Set 8 | palaikastron
# Processing Record 10 of Set 8 | buncrana
# Processing Record 11 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 8 | glenwood springs
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | bechem
# Processing Record 15 of Set 8 | lima
# Processing Record 16 of Set 8 | leh
# Processing Record 17 of Set 8 | birao
# Processing Record 18 of Set 8 | ulladulla
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | ponta delgada
# Processing Record 21 of Set 8 | lander
# Processing Record 22 of Set 8 | san joaquin
# Processing Record 23 of Set 8 | gerash
# Processing Record 24 of Set 8 | sola
# Processing Record 25 of Set 8 | krasnoselkup
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | shache
# Processing Record 28 of Set 8 | banyo
# Processing Record 29 of Set 8 | salym
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | cherskiy
# Processing Record 32 of Set 8 | chapais
# Processing Record 33 of Set 8 | praia
# Processing Record 34 of Set 8 | lucea
# Processing Record 35 of Set 8 | volchansk
# Processing Record 36 of Set 8 | hokitika
# Processing Record 37 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 8 | lavrentiya
# Processing Record 39 of Set 8 | zhigansk
# Processing Record 40 of Set 8 | fillira
# City not found. Skipping...
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | vanimo
# Processing Record 43 of Set 8 | evensk
# Processing Record 44 of Set 8 | kahului
# Processing Record 45 of Set 8 | fandriana
# Processing Record 46 of Set 8 | angoram
# Processing Record 47 of Set 8 | mnogovershinnyy
# Processing Record 48 of Set 8 | tsabong
# Processing Record 49 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 1 of Set 9 | jining
# Processing Record 2 of Set 9 | kota tinggi
# Processing Record 3 of Set 9 | magadan
# Processing Record 4 of Set 9 | uray
# Processing Record 5 of Set 9 | fallon
# Processing Record 6 of Set 9 | khanewal
# Processing Record 7 of Set 9 | ust-nera
# Processing Record 8 of Set 9 | rawson
# Processing Record 9 of Set 9 | wajir
# Processing Record 10 of Set 9 | diffa
# Processing Record 11 of Set 9 | great yarmouth
# Processing Record 12 of Set 9 | muromtsevo
# Processing Record 13 of Set 9 | yuza
# Processing Record 14 of Set 9 | umm lajj
# Processing Record 15 of Set 9 | margate
# Processing Record 16 of Set 9 | honningsvag
# Processing Record 17 of Set 9 | gotsu
# Processing Record 18 of Set 9 | kez
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | sistranda
# Processing Record 21 of Set 9 | moree
# Processing Record 22 of Set 9 | baijiantan
# Processing Record 23 of Set 9 | tazovskiy
# Processing Record 24 of Set 9 | eregli
# Processing Record 25 of Set 9 | mizque
# Processing Record 26 of Set 9 | dodge city
# Processing Record 27 of Set 9 | polunochnoye
# Processing Record 28 of Set 9 | caravelas
# Processing Record 29 of Set 9 | mangrol
# Processing Record 30 of Set 9 | ruston
# Processing Record 31 of Set 9 | mitsamiouli
# Processing Record 32 of Set 9 | oyama
# Processing Record 33 of Set 9 | eslamshahr
# Processing Record 34 of Set 9 | aitape
# Processing Record 35 of Set 9 | turukhansk
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | asfi
# Processing Record 38 of Set 9 | formosa
# Processing Record 39 of Set 9 | ust-maya
# Processing Record 40 of Set 9 | san luis rio colorado
# Processing Record 41 of Set 9 | kulhudhuffushi
# Processing Record 42 of Set 9 | jaque
# Processing Record 43 of Set 9 | laem sing
# Processing Record 44 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 9 | northam
# Processing Record 46 of Set 9 | klaksvik
# Processing Record 47 of Set 9 | pangkalanbuun
# Processing Record 48 of Set 9 | kyra
# Processing Record 49 of Set 9 | hobyo
# Processing Record 50 of Set 9 | farim
# Processing Record 1 of Set 10 | antofagasta
# Processing Record 2 of Set 10 | akcakoca
# Processing Record 3 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 10 | mayahi
# Processing Record 5 of Set 10 | kailua
# Processing Record 6 of Set 10 | pueblo nuevo
# Processing Record 7 of Set 10 | bend
# Processing Record 8 of Set 10 | sedhiou
# Processing Record 9 of Set 10 | puerto maldonado
# Processing Record 10 of Set 10 | thabazimbi
# Processing Record 11 of Set 10 | naze
# Processing Record 12 of Set 10 | berlevag
# Processing Record 13 of Set 10 | san quintin
# Processing Record 14 of Set 10 | staritsa
# Processing Record 15 of Set 10 | shitanjing
# Processing Record 16 of Set 10 | zhukovka
# Processing Record 17 of Set 10 | parana
# Processing Record 18 of Set 10 | faanui
# Processing Record 19 of Set 10 | cudahy
# Processing Record 20 of Set 10 | olot
# Processing Record 21 of Set 10 | bira
# Processing Record 22 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | marica
# Processing Record 24 of Set 10 | victoria
# Processing Record 25 of Set 10 | porto torres
# Processing Record 26 of Set 10 | zanjan
# Processing Record 27 of Set 10 | dengzhou
# Processing Record 28 of Set 10 | kedrovyy
# Processing Record 29 of Set 10 | gayeri
# Processing Record 30 of Set 10 | makakilo city
# Processing Record 31 of Set 10 | mason city
# Processing Record 32 of Set 10 | nanortalik
# Processing Record 33 of Set 10 | port lincoln
# Processing Record 34 of Set 10 | hervey bay
# Processing Record 35 of Set 10 | boysun
# Processing Record 36 of Set 10 | belle fourche
# Processing Record 37 of Set 10 | medicine hat
# Processing Record 38 of Set 10 | puerto del rosario
# Processing Record 39 of Set 10 | shenjiamen
# Processing Record 40 of Set 10 | bayan
# Processing Record 41 of Set 10 | kenitra
# Processing Record 42 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 10 | grand-lahou
# Processing Record 44 of Set 10 | bardiyah
# Processing Record 45 of Set 10 | maxixe
# Processing Record 46 of Set 10 | yangjiang
# Processing Record 47 of Set 10 | bodden town
# Processing Record 48 of Set 10 | vagur
# Processing Record 49 of Set 10 | shaoguan
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | varhaug
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | sungurlu
# Processing Record 4 of Set 11 | roma
# Processing Record 5 of Set 11 | usinsk
# Processing Record 6 of Set 11 | sovetskiy
# Processing Record 7 of Set 11 | along
# Processing Record 8 of Set 11 | marsh harbour
# Processing Record 9 of Set 11 | maldonado
# Processing Record 10 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 11 | grand-santi
# Processing Record 12 of Set 11 | vrangel
# Processing Record 13 of Set 11 | antigua ocotepeque
# Processing Record 14 of Set 11 | nouakchott
# Processing Record 15 of Set 11 | kokstad
# Processing Record 16 of Set 11 | san juan
# Processing Record 17 of Set 11 | stezzano
# Processing Record 18 of Set 11 | clyde river
# Processing Record 19 of Set 11 | aguimes
# Processing Record 20 of Set 11 | sitka
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | marystown
# Processing Record 23 of Set 11 | gobabis
# Processing Record 24 of Set 11 | sarangani
# Processing Record 25 of Set 11 | sungaipenuh
# Processing Record 26 of Set 11 | colares
# Processing Record 27 of Set 11 | berck
# Processing Record 28 of Set 11 | yulara
# Processing Record 29 of Set 11 | saint-francois
# Processing Record 30 of Set 11 | saskylakh
# Processing Record 31 of Set 11 | erenhot
# Processing Record 32 of Set 11 | arlit
# Processing Record 33 of Set 11 | tynda
# Processing Record 34 of Set 11 | abeokuta
# Processing Record 35 of Set 11 | clarksburg
# Processing Record 36 of Set 11 | port blair
# Processing Record 37 of Set 11 | airai
# Processing Record 38 of Set 11 | la ronge
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 11 | moindou
# Processing Record 43 of Set 11 | roebourne
# Processing Record 44 of Set 11 | nome
# Processing Record 45 of Set 11 | xinye
# Processing Record 46 of Set 11 | flin flon
# Processing Record 47 of Set 11 | coquimbo
# Processing Record 48 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 49 of Set 11 | udachnyy
# Processing Record 50 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 12 | lardos
# Processing Record 3 of Set 12 | termiz
# Processing Record 4 of Set 12 | ayan
# Processing Record 5 of Set 12 | arica
# Processing Record 6 of Set 12 | burnie
# Processing Record 7 of Set 12 | araouane
# Processing Record 8 of Set 12 | antalaha
# Processing Record 9 of Set 12 | winslow
# Processing Record 10 of Set 12 | lichinga
# Processing Record 11 of Set 12 | lethem
# Processing Record 12 of Set 12 | riyadh
# Processing Record 13 of Set 12 | korcula
# Processing Record 14 of Set 12 | uglegorsk
# Processing Record 15 of Set 12 | santa cruz
# Processing Record 16 of Set 12 | pisco
# Processing Record 17 of Set 12 | itamaraju
# Processing Record 18 of Set 12 | japura
# Processing Record 19 of Set 12 | guanica
# Processing Record 20 of Set 12 | luganville
# Processing Record 21 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 12 | saint-augustin
# Processing Record 24 of Set 12 | ovalle
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | kandrian
# Processing Record 27 of Set 12 | samastipur
# Processing Record 28 of Set 12 | ixtapa
# Processing Record 29 of Set 12 | jasper
# Processing Record 30 of Set 12 | beian
# Processing Record 31 of Set 12 | minatitlan
# Processing Record 32 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 12 | hit
# Processing Record 34 of Set 12 | istres
# Processing Record 35 of Set 12 | saint anthony
# Processing Record 36 of Set 12 | odweyne
# Processing Record 37 of Set 12 | obo
# Processing Record 38 of Set 12 | babushkin
# Processing Record 39 of Set 12 | gornopravdinsk
# Processing Record 40 of Set 12 | vilyuysk
# Processing Record 41 of Set 12 | kirensk
# Processing Record 42 of Set 12 | meulaboh
# Processing Record 43 of Set 12 | annau
# Processing Record 44 of Set 12 | sterling
# Processing Record 45 of Set 12 | muisne
# Processing Record 46 of Set 12 | tolaga bay
# Processing Record 47 of Set 12 | komsomolskiy
# Processing Record 48 of Set 12 | pecos
# Processing Record 49 of Set 12 | nyurba
# Processing Record 50 of Set 12 | kitahiroshima
# Processing Record 1 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 13 | mindif
# Processing Record 4 of Set 13 | dalby
# Processing Record 5 of Set 13 | kihei
# Processing Record 6 of Set 13 | porto walter
# Processing Record 7 of Set 13 | korsakov
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | lake charles
# Processing Record 10 of Set 13 | manicore
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | tarrafal
# Processing Record 13 of Set 13 | yerbogachen
# Processing Record 14 of Set 13 | zeya
# Processing Record 15 of Set 13 | mahon
# Processing Record 16 of Set 13 | grand island
# Processing Record 17 of Set 13 | mudgee
# Processing Record 18 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 13 | raudeberg
# Processing Record 20 of Set 13 | cubuk
# Processing Record 21 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 13 | moroni
# Processing Record 23 of Set 13 | brigantine
# Processing Record 24 of Set 13 | souillac
# Processing Record 25 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 13 | kieta
# Processing Record 27 of Set 13 | katangli
# Processing Record 28 of Set 13 | mabay
# Processing Record 29 of Set 13 | soure
# Processing Record 30 of Set 13 | solana beach
# Processing Record 31 of Set 13 | nakusp
# Processing Record 32 of Set 13 | perni
# Processing Record 33 of Set 13 | kavaratti
# Processing Record 34 of Set 13 | zhaoqing
# Processing Record 35 of Set 13 | saint-georges
# Processing Record 36 of Set 13 | neepawa
# Processing Record 37 of Set 13 | moerai
# Processing Record 38 of Set 13 | poum
# Processing Record 39 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 13 | olinda
# Processing Record 41 of Set 13 | taoudenni
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 44 of Set 13 | prado
# Processing Record 45 of Set 13 | arua
# Processing Record 46 of Set 13 | novyy urengoy
# Processing Record 47 of Set 13 | mongo
# Processing Record 48 of Set 13 | hovd
# Processing Record 49 of Set 13 | evanston
# Processing Record 50 of Set 13 | millerovo
# Processing Record 1 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 14 | rocha
# Processing Record 3 of Set 14 | seljord
# Processing Record 4 of Set 14 | buchanan
# Processing Record 5 of Set 14 | nelson bay
# Processing Record 6 of Set 14 | beihai
# Processing Record 7 of Set 14 | verkhniy baskunchak
# Processing Record 8 of Set 14 | vostok
# Processing Record 9 of Set 14 | manati
# Processing Record 10 of Set 14 | iwaki
# Processing Record 11 of Set 14 | rudbar
# Processing Record 12 of Set 14 | ambositra
# Processing Record 13 of Set 14 | kortkeros
# Processing Record 14 of Set 14 | charleston
# Processing Record 15 of Set 14 | severo-yeniseyskiy
# Processing Record 16 of Set 14 | kruisfontein
# Processing Record 17 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 14 | quelimane
# Processing Record 19 of Set 14 | lagos
# Processing Record 20 of Set 14 | herk-de-stad
# Processing Record 21 of Set 14 | avera
# Processing Record 22 of Set 14 | sorland
# Processing Record 23 of Set 14 | saint george
# Processing Record 24 of Set 14 | milyutinskaya
# Processing Record 25 of Set 14 | kiama
# Processing Record 26 of Set 14 | pokhara
# Processing Record 27 of Set 14 | madang
# Processing Record 28 of Set 14 | strelka
# Processing Record 29 of Set 14 | dera bugti
# Processing Record 30 of Set 14 | walvis bay
# Processing Record 31 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 14 | kharp
# Processing Record 33 of Set 14 | ishinomaki
# Processing Record 34 of Set 14 | koslan
# Processing Record 35 of Set 14 | soyo
# Processing Record 36 of Set 14 | liverpool
# Processing Record 37 of Set 14 | vredendal
# Processing Record 38 of Set 14 | sherbakul
# Processing Record 39 of Set 14 | goba
# Processing Record 40 of Set 14 | dunedin
# Processing Record 41 of Set 14 | le vauclin
# Processing Record 42 of Set 14 | apaxtla
# City not found. Skipping...
# Processing Record 43 of Set 14 | cravo norte
# Processing Record 44 of Set 14 | seoul
# Processing Record 45 of Set 14 | sibolga
# Processing Record 46 of Set 14 | mogocha
# Processing Record 47 of Set 14 | akhalgori
# Processing Record 48 of Set 14 | myitkyina
# Processing Record 49 of Set 14 | boyolangu
# Processing Record 50 of Set 14 | progreso
# Processing Record 1 of Set 15 | imbituba
# Processing Record 2 of Set 15 | loandjili
# Processing Record 3 of Set 15 | snasa
# Processing Record 4 of Set 15 | lazarev
# Processing Record 5 of Set 15 | ballina
# Processing Record 6 of Set 15 | yanam
# Processing Record 7 of Set 15 | skjervoy
# Processing Record 8 of Set 15 | namie
# Processing Record 9 of Set 15 | alofi
# Processing Record 10 of Set 15 | susehri
# Processing Record 11 of Set 15 | kangaatsiaq
# Processing Record 12 of Set 15 | umtata
# Processing Record 13 of Set 15 | dickinson
# Processing Record 14 of Set 15 | abu samrah
# Processing Record 15 of Set 15 | chifeng
# Processing Record 16 of Set 15 | elizabeth city
# Processing Record 17 of Set 15 | sioux lookout
# Processing Record 18 of Set 15 | catio
# Processing Record 19 of Set 15 | saint-joseph
# Processing Record 20 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 15 | zurrieq
# Processing Record 22 of Set 15 | arrifes
# Processing Record 23 of Set 15 | adrar
# Processing Record 24 of Set 15 | san cristobal
# Processing Record 25 of Set 15 | pontian kecil
# Processing Record 26 of Set 15 | aneho
# Processing Record 27 of Set 15 | kushmurun
# Processing Record 28 of Set 15 | flinders
# Processing Record 29 of Set 15 | andapa
# Processing Record 30 of Set 15 | sao miguel do araguaia
# Processing Record 31 of Set 15 | estelle
# Processing Record 32 of Set 15 | bud
# Processing Record 33 of Set 15 | zyryanka
# Processing Record 34 of Set 15 | kondopoga
# Processing Record 35 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 15 | ushumun
# Processing Record 37 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 15 | zelzate
# Processing Record 39 of Set 15 | dubbo
# Processing Record 40 of Set 15 | lae
# Processing Record 41 of Set 15 | pitangui
# Processing Record 42 of Set 15 | ketchikan
# Processing Record 43 of Set 15 | kamaishi
# Processing Record 44 of Set 15 | san policarpo
# Processing Record 45 of Set 15 | verkhnevilyuysk
# Processing Record 46 of Set 15 | gizo
# Processing Record 47 of Set 15 | mopti
# Processing Record 48 of Set 15 | kologriv
# Processing Record 49 of Set 15 | xuddur
# Processing Record 50 of Set 15 | kemijarvi
# Processing Record 1 of Set 16 | borba
# Processing Record 2 of Set 16 | imeni poliny osipenko
# Processing Record 3 of Set 16 | caraballeda
# Processing Record 4 of Set 16 | takoradi
# Processing Record 5 of Set 16 | kropotkin
# Processing Record 6 of Set 16 | aripuana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Port Alfred      ZA -33.5906   26.8910     56.17        94
# 1                 Galesong      ID  -5.3166  119.3661     83.48        71
# 2                  Rikitea      PF -23.1203 -134.9692     71.44        79
# 3                Cape Town      ZA -33.9258   18.4232     60.91        57
# 4            Alice Springs      AU -23.7000  133.8833     63.95        25
# ..                     ...     ...      ...       ...       ...       ...
# 694  Imeni Poliny Osipenko      RU  52.4201  136.4853     37.04        80
# 695            Caraballeda      VE  10.6112  -66.8522     84.27        70
# 696              Takoradze      GH   4.8845   -1.7554     78.76        84
# 697              Kropotkin      RU  45.4375   40.5756     37.67        60
# 698               Aripuanã      BR  -9.1667  -60.6333     74.97        91
#
#      Cloudiness  Wind Speed Current Description
# 0            98       11.12     overcast clouds
# 1            98        2.66     overcast clouds
# 2            30       13.76          light rain
# 3             0       17.00           clear sky
# 4             0       17.27           clear sky
# ..          ...         ...                 ...
# 694          71        5.97       broken clouds
# 695          75        6.91       broken clouds
# 696          96        4.23     overcast clouds
# 697           0        6.87           clear sky
# 698         100        3.27     overcast clouds
#
# [699 rows x 9 columns]
